# %%
from lexmachina import LexMachinaAsyncClient
from lexmachina import DistrictCaseQueryRequest
import asyncio
import datetime
from typing import Optional
from collections import defaultdict

# %%
client = LexMachinaAsyncClient(config_file_path='../config/config.ini')

# %% [markdown]
# Define three methods to help us retrieve the customized information:
# - a method to retrieve all cases from the API in which a given party appeared (perhaps in a given role) within a date range
# - a method to retieve the information we want from each of the returned case infos
# - a method to call the others and return the result

# %%
async def cases_for_party_role(start: str, end: str, party_id: int, role: Optional[str] = None):
    # Retrieve cases for a given party filed within a given date range.  
    # If specified limit the cases to only those in which the party was in a specific role.
    
    query = (
        DistrictCaseQueryRequest()
        .set_date(start, 'filed', 'onOrAfter')
        .set_date(end, 'filed', 'onOrBefore')
    )
    # Filter by role of the party, if specified
    if not role:
        query.include_parties(party_id)
    elif role.lower() == 'defendant':
        query.parties_include_defendant(party_id)
    elif role.lower() == 'plaintiff':
        query.parties_include_plaintiff(party_id)
    # return results as they come
    return await client.query_district_case(query=query, options={'pageThrough': True}, page_size=100)
    
    
def get_plaintiffs_attys_firms_and_judges(c):
    # Retrieve the information of interest
    
    judges = c['judges']
    
    plaintiffs = [p for p in c['parties'] if p['role'] == 'Plaintiff']
    plaintiff_ids = [p['partyId'] for p in plaintiffs]
    
    lawfirms = c['lawFirms']
    plaintiff_firms = [
        lf for lf in lawfirms 
        if all(party_id in plaintiff_ids for party_id in lf['clientPartyIds'])
    ]
    
    attys = c['attorneys']
    plaintiff_attys = [
        atty for atty in attys 
        if all(party_id in plaintiff_ids for party_id in atty['clientsPartyIds'])
    ]
    
    return plaintiffs, plaintiff_firms, plaintiff_attys, judges


async def plaintiff_centric_info_for_date_range(start: str, end: str, party_id: int, role: Optional[str] = None):
    
    # Get the case ids for all district cases that match the params
    case_infos = await cases_for_party_role(start, end, party_id, role)
    case_ids = list(c['districtCaseId'] for c in case_infos)
    print(f'there were {len(case_ids)} cases filed {start} and {end}')
    
    # Gather the case details for each in parallel, extract desired info
    cases = await asyncio.gather(*[client.get_district_cases(case) for case in case_ids])
    return [
        (c['districtCaseId'], *get_plaintiffs_attys_firms_and_judges(c))
        for c in cases
    ]

# %% [markdown]
# Define a class for aggregating the data of interest.  Here we are aggregating by Law Firm, but of course that can be adjusted to suit different information needs.

# %%
from collections import Counter

class AggregatedFirmInfo():
    def __init__(self, firm_id: int = None):
        self.firm_id = firm_id
        self.names = Counter()
        self.cases = []
        self.attys = Counter()
        self.parties = Counter()
    
    def name(self):
        return self.names.most_common(1)[0][0]
    
    def __str__(self):
        name_str = '\n\t\t'.join(str(n) for n in self.names.most_common())
        atty_str = '\n\t\t'.join(str(a) for a in self.attys.most_common())
        parties_str = '\n\t\t'.join(str(p) for p in self.parties.most_common())
        return f'''
        AggregatedFirmInfo({self.firm_id}): {self.name()}
         - cases in subset: {[f'https://law.lexmachina.com/cases/{c}' for c in self.cases]}
         - attys on those cases:\n\t\t{atty_str}
         - parties represented in those cases:\n\t\t{parties_str}
        '''

# %%
start_date = '2023-01-01'
end_date = str(datetime.date.today())
liberty_mutual = 39480
role='Defendant'

firm_data = defaultdict(AggregatedFirmInfo)

print(f"Plaintiff Attorney Activity since {start_date}:")
for c, plaintiff_parties, plaintiff_lfs, plaintiff_attys, judges in await plaintiff_centric_info_for_date_range(start_date, end_date, liberty_mutual, role):
    party_name_lut = {
        p['partyId']: p['name']
        for p in plaintiff_parties
    }
    
    for lf in plaintiff_lfs:
        firm_id = lf['lawFirmId']
        firm_data[firm_id].firm_id = firm_id
        firm_data[firm_id].names[lf['name']] += 1
        # Add to the case tally
        firm_data[firm_id].cases.append(c)
        # Add tallies for the parties represented, here aggregated by name.
        # Of course this can be done by id and converted later to prevent
        # unintentional party merging.
        for client_id in lf['clientPartyIds']:
            party_name = party_name_lut[client_id]
            firm_data[firm_id].parties[party_name] += 1
        
        
    for atty in plaintiff_attys:
        atty_name = atty['name']
        for firm_id in atty['lawFirmIds']:
            # Add tallies for the parties represented, here again, aggregated by name.
            if firm_id in firm_data:
                firm_data[firm_id].attys[atty_name] += 1
# Out:
# Plaintiff Attorney Activity since 2023-01-01:
# there were 218 cases filed 2023-01-01 and 2023-09-25

# %%
for firm_id, info in sorted(firm_data.items(), key=lambda tup: len(tup[1].cases), reverse=True):
    print(info)
# Out:
#         AggregatedFirmInfo(149043834): Cantrell Law Group
#          - cases in subset: ['https://law.lexmachina.com/cases/2009814932', 'https://law.lexmachina.com/cases/2009819044', 'https://law.lexmachina.com/cases/2009819048', 'https://law.lexmachina.com/cases/2009822800', 'https://law.lexmachina.com/cases/2009822813', 'https://law.lexmachina.com/cases/2009822881', 'https://law.lexmachina.com/cases/2009823193', 'https://law.lexmachina.com/cases/2009823958', 'https://law.lexmachina.com/cases/2009826116', 'https://law.lexmachina.com/cases/2009826206', 'https://law.lexmachina.com/cases/2009826292', 'https://law.lexmachina.com/cases/2009826588', 'https://law.lexmachina.com/cases/2009826651', 'https://law.lexmachina.com/cases/2009826729', 'https://law.lexmachina.com/cases/2009826730', 'https://law.lexmachina.com/cases/2009830091', 'https://law.lexmachina.com/cases/2009830306', 'https://law.lexmachina.com/cases/2009831472', 'https://law.lexmachina.com/cases/2009831493']
#          - attys on those cases:
# 		('Harry E. Cantrell Jr.', 19)
#          - parties represented in those cases:
# 		('Derek Brumfield', 1)
# 		('James Stewart', 1)
# 		('Sabra Banks', 1)
# 		('Betty Brown', 1)
# 		('John Hurst', 1)
# 		('Taurie Hoover', 1)
# 		('Renate Jones', 1)
# 		('Dianne Chesnut', 1)
# 		('Frank Green', 1)
# 		('Meah Badeaux', 1)
# 		('Darian Webb Gordon', 1)
# 		('Dewitt Madison', 1)
# 		('Matt Fiske', 1)
# 		('Tony Sanders', 1)
# 		('Bonnie Viveiros', 1)
# 		('Ronnie Martin', 1)
# 		('Michael A Marque', 1)
# 		('Betty McCaleb', 1)
# 		('Corey Major', 1)
#
#
#         AggregatedFirmInfo(185234158): Galindo Law Firm
#          - cases in subset: ['https://law.lexmachina.com/cases/2009819044', 'https://law.lexmachina.com/cases/2009822813', 'https://law.lexmachina.com/cases/2009822881', 'https://law.lexmachina.com/cases/2009823193', 'https://law.lexmachina.com/cases/2009826116', 'https://law.lexmachina.com/cases/2009826206', 'https://law.lexmachina.com/cases/2009826292', 'https://law.lexmachina.com/cases/2009826588', 'https://law.lexmachina.com/cases/2009826651', 'https://law.lexmachina.com/cases/2009826729', 'https://law.lexmachina.com/cases/2009826730', 'https://law.lexmachina.com/cases/2009830091', 'https://law.lexmachina.com/cases/2009831472', 'https://law.lexmachina.com/cases/2009831493']
#          - attys on those cases:
# 		('Mark Richard Ladd', 7)
# 		('Chinwe Onyenekwu', 7)
#          - parties represented in those cases:
# 		('James Stewart', 1)
# 		('John Hurst', 1)
# 		('Taurie Hoover', 1)
# 		('Renate Jones', 1)
# 		('Frank Green', 1)
# 		('Meah Badeaux', 1)
# 		('Darian Webb Gordon', 1)
# 		('Dewitt Madison', 1)
# 		('Matt Fiske', 1)
# 		('Tony Sanders', 1)
# 		('Bonnie Viveiros', 1)
# 		('Ronnie Martin', 1)
# 		('Betty McCaleb', 1)
# 		('Corey Major', 1)
#
#
#         AggregatedFirmInfo(57648735): Cristobal M. Galindo
#          - cases in subset: ['https://law.lexmachina.com/cases/2009814932', 'https://law.lexmachina.com/cases/2009822800', 'https://law.lexmachina.com/cases/2009822813', 'https://law.lexmachina.com/cases/2009822881', 'https://law.lexmachina.com/cases/2009823958', 'https://law.lexmachina.com/cases/2009826116', 'https://law.lexmachina.com/cases/2009826206', 'https://law.lexmachina.com/cases/2009826292', 'https://law.lexmachina.com/cases/2009826588', 'https://law.lexmachina.com/cases/2009830091', 'https://law.lexmachina.com/cases/2009830306']
#          - attys on those cases:
# 		('Mark Richard Ladd', 11)
#          - parties represented in those cases:
# 		('Derek Brumfield', 1)
# 		('Betty Brown', 1)
# 		('John Hurst', 1)
# 		('Taurie Hoover', 1)
# 		('Dianne Chesnut', 1)
# 		('Frank Green', 1)
# 		('Meah Badeaux', 1)
# 		('Darian Webb Gordon', 1)
# 		('Dewitt Madison', 1)
# 		('Ronnie Martin', 1)
# 		('Michael A Marque', 1)
#
#
#         AggregatedFirmInfo(9002389): Robichaux, Mize, Wadsack, Richardson & Watson
#          - cases in subset: ['https://law.lexmachina.com/cases/2008568571', 'https://law.lexmachina.com/cases/2008619003', 'https://law.lexmachina.com/cases/2009807220', 'https://law.lexmachina.com/cases/2009822927', 'https://law.lexmachina.com/cases/2009826701']
#          - attys on those cases:
# 		('Matthew Martin Mize', 5)
# 		('Tristan Gregory Gruspier', 2)
#          - parties represented in those cases:
# 		('Larry Puma', 1)
# 		('Glenva Puma', 1)
# 		('Linnie Montgomery', 1)
# 		('Wesley Courtney', 1)
# 		('Sherry Courtney', 1)
# 		('Keith Lauf', 1)
# 		('Tricia Lauf', 1)
# 		('Jimmy Walley', 1)
#
#
#         AggregatedFirmInfo(11046354): Pandit Law
#          - cases in subset: ['https://law.lexmachina.com/cases/2008568571', 'https://law.lexmachina.com/cases/2008619003', 'https://law.lexmachina.com/cases/2009807220', 'https://law.lexmachina.com/cases/2009822927', 'https://law.lexmachina.com/cases/2009826701']
#          - attys on those cases:
# 		('Rajan Pandit', 5)
# 		('Keith Martin Frey', 2)
# 		('John Edward Carr III', 1)
# 		('Kevin M. Melchi', 1)
# 		('David B. Wheeler (Pandit Law Firm)', 1)
#          - parties represented in those cases:
# 		('Larry Puma', 1)
# 		('Glenva Puma', 1)
# 		('Linnie Montgomery', 1)
# 		('Wesley Courtney', 1)
# 		('Sherry Courtney', 1)
# 		('Keith Lauf', 1)
# 		('Tricia Lauf', 1)
# 		('Jimmy Walley', 1)
#
#
#         AggregatedFirmInfo(425882): Alvendia, Kelly, & Demarest
#          - cases in subset: ['https://law.lexmachina.com/cases/2008514674', 'https://law.lexmachina.com/cases/2009018859', 'https://law.lexmachina.com/cases/2009089588', 'https://law.lexmachina.com/cases/2009767984']
#          - attys on those cases:
# 		('John Bartholomew Kelly III', 4)
# 		('Roderick Rico Alvendia', 4)
# 		('Jeanne Katherine Demarest', 4)
# 		('Kurt Alan Offner', 4)
# 		('Cassie Preston Gailmor', 4)
# 		('Jennifer Lynn Kuechmann', 4)
# 		('Thomas M. Wilson (Alvendia, Kelly, & Demarest)', 1)
# 		('Laurie White', 1)
# 		('Zachary Cambre', 1)
# 		('Cindy Cambre', 1)
#          - parties represented in those cases:
# 		('Zachary Cambre', 2)
# 		('Cindy Cambre', 2)
# 		('Laurie White', 1)
# 		('Thomas M Wilson', 1)
# 		('Zachary G. Cambre', 1)
# 		('Cindy R. Cambre', 1)
# 		('Jack Siciliano', 1)
# 		('Gail Siciliano', 1)
#
#
#         AggregatedFirmInfo(103564545): Hair Shunnarah Trial Attorneys
#          - cases in subset: ['https://law.lexmachina.com/cases/2008575876', 'https://law.lexmachina.com/cases/2008863274', 'https://law.lexmachina.com/cases/2008994754', 'https://law.lexmachina.com/cases/2009834976']
#          - attys on those cases:
# 		('Galen Matthew Hair', 4)
# 		('Gretchen Liljeberg Casey', 1)
# 		('Raven Anne Bourque', 1)
# 		('Mary Kate Taliancich', 1)
#          - parties represented in those cases:
# 		('Brian Alexander', 1)
# 		('Baton Rouge Master Barbers DBA Brent L. Sims', 1)
# 		('Baton Rouge Master Barbers', 1)
# 		('Lisa Aucoin', 1)
# 		('David Aucoin', 1)
# 		('Sarah Diano', 1)
# 		('Philip Diano', 1)
#
#
#         AggregatedFirmInfo(134555995): Philip C. Hoffman
#          - cases in subset: ['https://law.lexmachina.com/cases/2008975852', 'https://law.lexmachina.com/cases/2009817637', 'https://law.lexmachina.com/cases/2009817840']
#          - attys on those cases:
# 		('Philip Charles Hoffman', 3)
#          - parties represented in those cases:
# 		('Darwin Kraemer', 1)
# 		('Roseanne Pierron', 1)
# 		('Wendy Vonlienen', 1)
# 		('Cheryl Becnel', 1)
# 		('Marvin Evans', 1)
# 		('Michael Simoneaux', 1)
#
#
#         AggregatedFirmInfo(176991800): Dayal Reddy
#          - cases in subset: ['https://law.lexmachina.com/cases/2008975852', 'https://law.lexmachina.com/cases/2009817637', 'https://law.lexmachina.com/cases/2009817840']
#          - attys on those cases:
# 		('Dayal Syamala Reddy', 3)
#          - parties represented in those cases:
# 		('Darwin Kraemer', 1)
# 		('Roseanne Pierron', 1)
# 		('Wendy Vonlienen', 1)
# 		('Cheryl Becnel', 1)
# 		('Marvin Evans', 1)
# 		('Michael Simoneaux', 1)
#
#
#         AggregatedFirmInfo(116595349): Your Insurance Attorney
#          - cases in subset: ['https://law.lexmachina.com/cases/2009331583', 'https://law.lexmachina.com/cases/2009775775', 'https://law.lexmachina.com/cases/2009783750']
#          - attys on those cases:
# 		('Joshua Roger Lopez', 2)
# 		('Rotceh Sotomayor', 2)
# 		('John Michael Kelly', 1)
# 		('Mariela Elisa Cano', 1)
#          - parties represented in those cases:
# 		('Yesenia Rivera', 3)
# 		('Mark A. Rivera', 3)
#
#
#         AggregatedFirmInfo(182080061): Averill & Reaney Counselors at Law
#          - cases in subset: ['https://law.lexmachina.com/cases/2009373746', 'https://law.lexmachina.com/cases/2009438075', 'https://law.lexmachina.com/cases/2009822871']
#          - attys on those cases:
# 		('Brian Gerard Reaney II', 3)
# 		('Matthew J. Averill', 3)
#          - parties represented in those cases:
# 		('Wakeelah Thompson', 1)
# 		('Joseph W. Batt', 1)
# 		('Gary Dubuc', 1)
#
#
#         AggregatedFirmInfo(768322): Ryan Whaley Coldiron Shandy
#          - cases in subset: ['https://law.lexmachina.com/cases/2008521638', 'https://law.lexmachina.com/cases/2008548694']
#          - attys on those cases:
# 		('Gerard F. Pignato', 2)
# 		('Matthew Colin Kane', 1)
#          - parties represented in those cases:
# 		('Clay Gilliland', 1)
# 		('Brandi Gilliland', 1)
# 		('Brent Wensauer', 1)
# 		('Katherine Wensauer', 1)
#
#
#         AggregatedFirmInfo(146381715): Boling Law Firm
#          - cases in subset: ['https://law.lexmachina.com/cases/2008551132', 'https://law.lexmachina.com/cases/2008854086']
#          - attys on those cases:
# 		('Jeremiah Spencer Boling', 2)
# 		('Benjamin David Rumph', 2)
# 		('Caroline Boling', 2)
# 		('LaCrisha McAllister', 2)
# 		('Adam David Whitworth', 1)
#          - parties represented in those cases:
# 		('Kelvin White', 1)
# 		('Keith Rodriguez', 1)
#
#
#         AggregatedFirmInfo(4378): Adams & Reese
#          - cases in subset: ['https://law.lexmachina.com/cases/2008611187', 'https://law.lexmachina.com/cases/2008616815']
#          - attys on those cases:
# 		('Benjamin Michael Rachelson', 2)
# 		('Samuel Richards (Adams & Reese)', 2)
#          - parties represented in those cases:
# 		('SES Group, Inc.', 1)
# 		('Keller North America, Inc.', 1)
#
#
#         AggregatedFirmInfo(2414687): Baron & Budd
#          - cases in subset: ['https://law.lexmachina.com/cases/2008623416', 'https://law.lexmachina.com/cases/2009530859']
#          - attys on those cases:
# 		('David Ryan Cannella', 2)
# 		('Christopher C. Colley', 2)
# 		('Kristopher Lynn Thompson', 2)
# 		('Emily Catherine LaCerte', 2)
#          - parties represented in those cases:
# 		('Irma Lee Lagrange', 1)
# 		('David Gomez', 1)
#
#
#         AggregatedFirmInfo(48900721): The Hodge Law Firm
#          - cases in subset: ['https://law.lexmachina.com/cases/2008755815', 'https://law.lexmachina.com/cases/2009783595']
#          - attys on those cases:
# 		('Shaun Wesley Hodge', 2)
# 		('Michael Edward Cooper', 1)
# 		('Mustapha Nyallay', 1)
#          - parties represented in those cases:
# 		('Scott Guilfoyle', 1)
# 		('MARIA VARGAS', 1)
# 		('JOSE VARGAS', 1)
#
#
#         AggregatedFirmInfo(15810746): Hunter & Cassidy
#          - cases in subset: ['https://law.lexmachina.com/cases/2008992157', 'https://law.lexmachina.com/cases/2008992164']
#          - attys on those cases:
# 		('Micah Lacerte', 1)
# 		('Diana Chaloux-Lacerte', 1)
# 		('Dennis J. Cassidy', 1)
#          - parties represented in those cases:
# 		('Micah Lacerte', 2)
# 		('Diana Chaloux-Lacerte', 2)
#
#
#         AggregatedFirmInfo(49104348): Morgan & Associates (morganlawgroup.net)
#          - cases in subset: ['https://law.lexmachina.com/cases/2009000442', 'https://law.lexmachina.com/cases/2009821733']
#          - attys on those cases:
# 		('Brian Gerard Reaney II', 1)
# 		('Matthew J. Averill', 1)
# 		('Thomas Jeremiah Morgan Jr.', 1)
# 		('Nino Miguel Rishmague', 1)
# 		('Geovanna Vazquez', 1)
#          - parties represented in those cases:
# 		('Garry R. Pittman', 1)
# 		('Doreen W. Pittman', 1)
# 		('Alicia Dennis', 1)
# 		('Brian Dennis', 1)
#
#
#         AggregatedFirmInfo(18135662): Dudley DeBosier Injury Lawyers
#          - cases in subset: ['https://law.lexmachina.com/cases/2009006188', 'https://law.lexmachina.com/cases/2009350727']
#          - attys on those cases:
# 		('Michael Thiel Beckers', 1)
# 		('Richard Villere Kohnke Jr.', 1)
# 		('Brent Paul Frederick', 1)
# 		('Kenneth M. Miller (Dudley DeBosier Injury Lawyers)', 1)
# 		('Eric M. Landry', 1)
# 		("Loretta O'Boyle Hoskins", 1)
# 		('Brandi Taulli', 1)
#          - parties represented in those cases:
# 		('Linda Jefferson', 1)
# 		('Brandi Taulli', 1)
#
#
#         AggregatedFirmInfo(58630519): Joseph Rochelle, Attorney-at-Law
#          - cases in subset: ['https://law.lexmachina.com/cases/2009018859', 'https://law.lexmachina.com/cases/2009767984']
#          - attys on those cases:
# 		('Joseph B. Rochelle', 2)
#          - parties represented in those cases:
# 		('Zachary G. Cambre', 1)
# 		('Cindy R. Cambre', 1)
# 		('Zachary Cambre', 1)
# 		('Cindy Cambre', 1)
#
#
#         AggregatedFirmInfo(1278422): Nicaud & Sunseri
#          - cases in subset: ['https://law.lexmachina.com/cases/2009031542', 'https://law.lexmachina.com/cases/2009437958']
#          - attys on those cases:
# 		('Joseph Douglas Sunseri', 2)
# 		('Kathryn A. E. Sunseri', 2)
# 		('Cameron J. Windham', 1)
#          - parties represented in those cases:
# 		('Kerri Loiacono', 1)
# 		('Nick Loiacono', 1)
# 		('Susan Arthur', 1)
#
#
#         AggregatedFirmInfo(8187404): Bowling & McKinney
#          - cases in subset: ['https://law.lexmachina.com/cases/2009038154', 'https://law.lexmachina.com/cases/2009537455']
#          - attys on those cases:
# 		('Zachary Ryan Christiansen', 2)
# 		('David Alexander Bowling', 1)
#          - parties represented in those cases:
# 		('Roy DiVittorio', 1)
# 		('Roy J DiVittorio', 1)
# 		('Anthony Burton', 1)
# 		('Brenda Burton', 1)
#
#
#         AggregatedFirmInfo(2538578): Offit Kurman
#          - cases in subset: ['https://law.lexmachina.com/cases/2009283266', 'https://law.lexmachina.com/cases/2009368321']
#          - attys on those cases:
# 		('Edward Jay Tolchin', 1)
# 		('Sarah Rachel Goodman', 1)
# 		('Anthony Nicholas Delcollo', 1)
# 		('Thomas H. Kramer', 1)
#          - parties represented in those cases:
# 		('DISTRICT VETERANS CONTRACTING, INC.', 1)
# 		('Ralph G. Degli Obizzi & Sons, Inc.', 1)
#
#
#         AggregatedFirmInfo(48494845): Daly & Black
#          - cases in subset: ['https://law.lexmachina.com/cases/2009536538', 'https://law.lexmachina.com/cases/2009757561']
#          - attys on those cases:
# 		('Aaron Jason Hurd', 2)
# 		('Phillip Norris Sanov', 1)
#          - parties represented in those cases:
# 		('Linda Gurvin', 1)
# 		('Thomas Walker', 1)
#
#
#         AggregatedFirmInfo(185016831): Brown & Associates (tbrownandassociates.com)
#          - cases in subset: ['https://law.lexmachina.com/cases/2009822800', 'https://law.lexmachina.com/cases/2009823958']
#          - attys on those cases:
# 		('Chinwe Onyenekwu', 2)
#          - parties represented in those cases:
# 		('Betty Brown', 1)
# 		('Dianne Chesnut', 1)
#
#
#         AggregatedFirmInfo(44719413): Delise & Hall
#          - cases in subset: ['https://law.lexmachina.com/cases/2008514674']
#          - attys on those cases:
# 		('Bobby Joseph Delise', 1)
#          - parties represented in those cases:
# 		('Laurie White', 1)
# 		('Thomas M Wilson', 1)
#
#
#         AggregatedFirmInfo(32081072): Salvatore' G. Lovecchio, Attorney at Law
#          - cases in subset: ['https://law.lexmachina.com/cases/2008515158']
#          - attys on those cases:
# 		("Salvatore' George Lovecchio", 1)
# 		('Karen Wiedemann', 1)
#          - parties represented in those cases:
# 		('Karen Wiedemann', 1)
# 		('Salvatore G. Lovecchio', 1)
#
#
#         AggregatedFirmInfo(124626683): Clayton B. Bruner, P.L.L.C., Attorney At Law
#          - cases in subset: ['https://law.lexmachina.com/cases/2008521638']
#          - attys on those cases:
# 		('Clayton Barrett Bruner', 1)
#          - parties represented in those cases:
# 		('Clay Gilliland', 1)
# 		('Brandi Gilliland', 1)
#
#
#         AggregatedFirmInfo(8178): Connolly Gallagher
#          - cases in subset: ['https://law.lexmachina.com/cases/2008529873']
#          - attys on those cases:
# 		('Lauren Patrice DeLuca', 1)
# 		('Aaron Max Shapiro', 1)
# 		('Benjamin T. Forman', 1)
#          - parties represented in those cases:
# 		('RC Fabricators, Inc.', 1)
#
#
#         AggregatedFirmInfo(1723524): Murr Yanochik
#          - cases in subset: ['https://law.lexmachina.com/cases/2008534720']
#          - attys on those cases:
# 		('George Bashier Murr', 1)
#          - parties represented in those cases:
# 		('Ricardo Baltrell', 1)
# 		('Leticia Baltrell', 1)
#
#
#         AggregatedFirmInfo(8070076): Nachawati Law Group
#          - cases in subset: ['https://law.lexmachina.com/cases/2008534720']
#          - attys on those cases:
# 		('John Warren Raggio', 1)
#          - parties represented in those cases:
# 		('Ricardo Baltrell', 1)
# 		('Leticia Baltrell', 1)
#
#
#         AggregatedFirmInfo(6086046): Napoli Shkolnik
#          - cases in subset: ['https://law.lexmachina.com/cases/2008537041']
#          - attys on those cases:
# 		('Joseph Peter Napoli', 1)
#          - parties represented in those cases:
# 		('Frank Caldwell', 1)
#
#
#         AggregatedFirmInfo(2902876): The Nelson Law Chambers
#          - cases in subset: ['https://law.lexmachina.com/cases/2008551140']
#          - attys on those cases:
# 		('John William Nelson', 1)
#          - parties represented in those cases:
# 		('Gregory Bennett', 1)
#
#
#         AggregatedFirmInfo(14982951): DeWoskin Law Firm
#          - cases in subset: ['https://law.lexmachina.com/cases/2008551140']
#          - attys on those cases:
# 		('Daniel Eliot DeWoskin', 1)
#          - parties represented in those cases:
# 		('Gregory Bennett', 1)
#
#
#         AggregatedFirmInfo(69294712): Katz Law (joekatzlaw.com)
#          - cases in subset: ['https://law.lexmachina.com/cases/2008551016']
#          - attys on those cases:
# 		('Joseph Larry Katz', 1)
#          - parties represented in those cases:
# 		('SPECIALTY POOL & FOUNTAIN, INC.', 1)
#
#
#         AggregatedFirmInfo(10026789): Law Office of Daniel S Levinson
#          - cases in subset: ['https://law.lexmachina.com/cases/2008554814']
#          - attys on those cases:
# 		('Daniel Saul Levinson', 1)
#          - parties represented in those cases:
# 		('San Diego Gold Exchange, Inc.', 1)
#
#
#         AggregatedFirmInfo(16994): Dovel & Luner
#          - cases in subset: ['https://law.lexmachina.com/cases/2008557675']
#          - attys on those cases:
# 		('Richard Elgar Lyon III', 1)
# 		('Simon Carlo Franzini', 1)
# 		('Jonas Bram Jacobson', 1)
#          - parties represented in those cases:
# 		('Impressions Restaurant and Banquet Hall Inc.', 1)
#
#
#         AggregatedFirmInfo(8272908): Romanucci & Blandin
#          - cases in subset: ['https://law.lexmachina.com/cases/2008557675']
#          - attys on those cases:
# 		('David Adam Neiman', 1)
#          - parties represented in those cases:
# 		('Impressions Restaurant and Banquet Hall Inc.', 1)
#
#
#         AggregatedFirmInfo(25244882): Rogers, Ehrhardt, Weber & Howard
#          - cases in subset: ['https://law.lexmachina.com/cases/2008559972']
#          - attys on those cases:
# 		('Elizabeth H. Weber', 1)
# 		('James R. Howard', 1)
# 		('Glen Ray Ehrhardt', 1)
# 		('David Roy Wallis', 1)
#          - parties represented in those cases:
# 		('Acuity, A Mutual Insurance Company', 1)
#
#
#         AggregatedFirmInfo(173262538): Shapiro Law Team
#          - cases in subset: ['https://law.lexmachina.com/cases/2008969862']
#          - attys on those cases:
# 		('David Carey Shapiro (David Shapiro Law)', 1)
#          - parties represented in those cases:
# 		('Wendy Lynn Laven', 1)
#
#
#         AggregatedFirmInfo(51124): Knox McLaughlin Gornall & Sennett
#          - cases in subset: ['https://law.lexmachina.com/cases/2008565099']
#          - attys on those cases:
# 		('Bryan Geoffrey Baumann', 1)
#          - parties represented in those cases:
# 		('INSULATION COATINGS & CONSULTANTS, LLC', 1)
#
#
#         AggregatedFirmInfo(9007371): Colligan Law
#          - cases in subset: ['https://law.lexmachina.com/cases/2008565099']
#          - attys on those cases:
# 		('Frederick J. Gawronski', 1)
# 		('Erick Daniel Kraemer', 1)
#          - parties represented in those cases:
# 		('INSULATION COATINGS & CONSULTANTS, LLC', 1)
#
#
#         AggregatedFirmInfo(10648318): Gertler, Gertler, Vincent & Plotkin
#          - cases in subset: ['https://law.lexmachina.com/cases/2008565129']
#          - attys on those cases:
# 		('Helen Hairston Babin', 1)
# 		('Louis L. Gertler', 1)
#          - parties represented in those cases:
# 		('Felicia Cadiere Bourgeois', 1)
# 		('Michael Cadiere', 1)
# 		('Bradley J Cadiere, Sr.', 1)
# 		('Bradley Joseph Cadiere, Sr.', 1)
#
#
#         AggregatedFirmInfo(8072574): Marc Whitehead & Associates
#          - cases in subset: ['https://law.lexmachina.com/cases/2008570646']
#          - attys on those cases:
# 		('John Anthony Vessel', 1)
#          - parties represented in those cases:
# 		('LAUREL RICHARDSON', 1)
#
#
#         AggregatedFirmInfo(10478772): Hankey Law Office
#          - cases in subset: ['https://law.lexmachina.com/cases/2008570646']
#          - attys on those cases:
# 		('Melissa A. Davidson', 1)
#          - parties represented in those cases:
# 		('LAUREL RICHARDSON', 1)
#
#
#         AggregatedFirmInfo(113791851): Broussard & Williamson
#          - cases in subset: ['https://law.lexmachina.com/cases/2008575876']
#          - attys on those cases:
# 		('Myles Drew Ranier', 1)
#          - parties represented in those cases:
# 		('Brian Alexander', 1)
#
#
#         AggregatedFirmInfo(1707733): Kirwin Norris
#          - cases in subset: ['https://law.lexmachina.com/cases/2008595148']
#          - attys on those cases:
# 		('Douglas W. Ackerman', 1)
# 		('Brian Patrick Kirwin', 1)
#          - parties represented in those cases:
# 		('United States for the use and benefit of Randall Mechanical, Inc.', 1)
# 		('United States for the use and benefit of Randall Electrical Contractors, Inc.', 1)
# 		('Randall Electrical Contractors, Inc.', 1)
# 		('Randall Mechanical, Inc.', 1)
# 		('United States of America', 1)
#
#
#         AggregatedFirmInfo(49002577): S.R. Mikiciuk
#          - cases in subset: ['https://law.lexmachina.com/cases/2008595475']
#          - attys on those cases:
# 		('Stanley R. Mikiciuk', 1)
#          - parties represented in those cases:
# 		('TAA FAIRLANE PROPERTY, LLC', 1)
#
#
#         AggregatedFirmInfo(9134291): Aegis Law Firm
#          - cases in subset: ['https://law.lexmachina.com/cases/2008651941']
#          - attys on those cases:
# 		('Arindam Kar', 1)
# 		('Sheldon David Korlin', 1)
# 		('Theodore Gordon Hughes IV', 1)
#          - parties represented in those cases:
# 		('Arindam Kar', 1)
# 		('Shanna Kar', 1)
#
#
#         AggregatedFirmInfo(51394203): Kandell, Kandell & Petrie
#          - cases in subset: ['https://law.lexmachina.com/cases/2008709293']
#          - attys on those cases:
# 		('Elise Belen Barimo', 1)
#          - parties represented in those cases:
# 		('Mark Ferran', 1)
#
#
#         AggregatedFirmInfo(171052105): SID#1270293
#          - cases in subset: ['https://law.lexmachina.com/cases/2008742160']
#          - attys on those cases:
# 		('Robert Clifford Weddington', 1)
#          - parties represented in those cases:
# 		('Robert C. Weddington', 1)
#
#
#         AggregatedFirmInfo(53081058): The Joseph Dedvukaj Firm
#          - cases in subset: ['https://law.lexmachina.com/cases/2008773932']
#          - attys on those cases:
# 		('Joseph Dedvukaj', 1)
#          - parties represented in those cases:
# 		('CHERISSE CASAR WILSON', 1)
#
#
#         AggregatedFirmInfo(15901454): Smith Collins
#          - cases in subset: ['https://law.lexmachina.com/cases/2008784987']
#          - attys on those cases:
# 		('Steven Lewis Smith', 1)
#          - parties represented in those cases:
# 		('Sierras Construction LLC', 1)
#
#
#         AggregatedFirmInfo(8677149): Pmb 537
#          - cases in subset: ['https://law.lexmachina.com/cases/2008783413']
#          - attys on those cases:
# 		('Eduardo R. Jenks-Carballeira', 1)
#          - parties represented in those cases:
# 		('Rolanda Murphy', 1)
#
#
#         AggregatedFirmInfo(43189932): Rivera Aspinall, Garriga & Fernandini
#          - cases in subset: ['https://law.lexmachina.com/cases/2008783413']
#          - attys on those cases:
# 		('Julian R. Rivera-Aspinall', 1)
#          - parties represented in those cases:
# 		('Rolanda Murphy', 1)
#
#
#         AggregatedFirmInfo(18616881): Mountain State Justice
#          - cases in subset: ['https://law.lexmachina.com/cases/2008840481']
#          - attys on those cases:
# 		('Sarah K. Brown', 1)
# 		('Colten Lewis Fleu', 1)
# 		('Ian Matthew Shoulders', 1)
#          - parties represented in those cases:
# 		('David F. Legg', 1)
# 		('Mary R. Legg', 1)
#
#
#         AggregatedFirmInfo(17040555): Scott & Associates (38scott.com)
#          - cases in subset: ['https://law.lexmachina.com/cases/2008863272']
#          - attys on those cases:
# 		('Lindsey Mitchell Scott', 1)
#          - parties represented in those cases:
# 		('Freddie L Dukes', 1)
#
#
#         AggregatedFirmInfo(167571364): Hair Shunnarah
#          - cases in subset: ['https://law.lexmachina.com/cases/2008863274']
#          - attys on those cases:
# 		('Christopher Gerald Otten', 1)
#          - parties represented in those cases:
# 		('Baton Rouge Master Barbers', 1)
#
#
#         AggregatedFirmInfo(13585138): Kimmel & Silverman
#          - cases in subset: ['https://law.lexmachina.com/cases/2008889701']
#          - attys on those cases:
# 		('Craig Thor Kimmel', 1)
# 		('Jacob Uri Ginsburg', 1)
#          - parties represented in those cases:
# 		('Jeffrey R. Scott', 1)
#
#
#         AggregatedFirmInfo(37392033): The Weitz Firm
#          - cases in subset: ['https://law.lexmachina.com/cases/2008889701']
#          - attys on those cases:
# 		('Max Scott Morgan', 1)
#          - parties represented in those cases:
# 		('Jeffrey R. Scott', 1)
#
#
#         AggregatedFirmInfo(160157219): Ginsburg Law Office
#          - cases in subset: ['https://law.lexmachina.com/cases/2008889701']
#          - attys on those cases:
# 		('Jacob Uri Ginsburg', 1)
#          - parties represented in those cases:
# 		('Jeffrey R. Scott', 1)
#
#
#         AggregatedFirmInfo(16064833): Hagan & Farrar
#          - cases in subset: ['https://law.lexmachina.com/cases/2008905857']
#          - attys on those cases:
# 		('Mary Beth Hagan', 1)
#          - parties represented in those cases:
# 		('Century Fire Protection, LLC', 1)
#
#
#         AggregatedFirmInfo(168009495): The Roth Group
#          - cases in subset: ['https://law.lexmachina.com/cases/2008912961']
#          - attys on those cases:
# 		('David Martin Roth', 1)
#          - parties represented in those cases:
# 		('Christine Diehl', 1)
# 		('Ben Diehl', 1)
#
#
#         AggregatedFirmInfo(171739350): Rex Legal
#          - cases in subset: ['https://law.lexmachina.com/cases/2008912961']
#          - attys on those cases:
# 		('Michael D. Rex', 1)
#          - parties represented in those cases:
# 		('Christine Diehl', 1)
# 		('Ben Diehl', 1)
#
#
#         AggregatedFirmInfo(58695279): Stokes Law Office (Brian Stokes)
#          - cases in subset: ['https://law.lexmachina.com/cases/2008913829']
#          - attys on those cases:
# 		('Brian Stokes', 1)
#          - parties represented in those cases:
# 		('Scott Fredman', 1)
#
#
#         AggregatedFirmInfo(172786281): LAW OFFICES OF JEROME LT LEFTON
#          - cases in subset: ['https://law.lexmachina.com/cases/2008913829']
#          - attys on those cases:
# 		('Aaron D. Lefton', 1)
#          - parties represented in those cases:
# 		('Scott Fredman', 1)
#
#
#         AggregatedFirmInfo(49192624): GLP Attorneys
#          - cases in subset: ['https://law.lexmachina.com/cases/2008947600']
#          - attys on those cases:
# 		('Scott Shawver', 1)
#          - parties represented in those cases:
# 		('Jason Risinger', 1)
#
#
#         AggregatedFirmInfo(50429520): Craig Swapp & Associates
#          - cases in subset: ['https://law.lexmachina.com/cases/2008947600']
#          - attys on those cases:
# 		('Erin C. Dyer', 1)
#          - parties represented in those cases:
# 		('Jason Risinger', 1)
#
#
#         AggregatedFirmInfo(57841383): Law Office of David A. Johnson
#          - cases in subset: ['https://law.lexmachina.com/cases/2008930371']
#          - attys on those cases:
# 		('Justin Wade Noble', 1)
# 		('Michael Anthony Johnson', 1)
#          - parties represented in those cases:
# 		('Rhonda Sexton', 1)
# 		('Josh Sexton', 1)
#
#
#         AggregatedFirmInfo(120798): Fracassi Mahdavi Sissman & Rand
#          - cases in subset: ['https://law.lexmachina.com/cases/2008947078']
#          - attys on those cases:
# 		('Richard Michael Sissman', 1)
#          - parties represented in those cases:
# 		('American Builders & Contractors Supply Co., Inc.', 1)
#
#
#         AggregatedFirmInfo(173066928): Richard M. Sissman, Esquire
#          - cases in subset: ['https://law.lexmachina.com/cases/2008947078']
#          - attys on those cases:
# 		('Richard Michael Sissman', 1)
#          - parties represented in those cases:
# 		('American Builders & Contractors Supply Co., Inc.', 1)
#
#
#         AggregatedFirmInfo(28386961): Law Office of Glenn Verchick
#          - cases in subset: ['https://law.lexmachina.com/cases/2008948267']
#          - attys on those cases:
# 		('Glenn Verchick', 1)
#          - parties represented in those cases:
# 		('BENJAMIN M. GOLDSMITH', 1)
#
#
#         AggregatedFirmInfo(170220416): Baxter Law Firm (baxlegal.com)
#          - cases in subset: ['https://law.lexmachina.com/cases/2008971861']
#          - attys on those cases:
# 		('Ryan D. Baxter', 1)
#          - parties represented in those cases:
# 		('Rachel Patterson', 1)
#
#
#         AggregatedFirmInfo(857417): Sell & Melton
#          - cases in subset: ['https://law.lexmachina.com/cases/2008972056']
#          - attys on those cases:
# 		('Richard Bruce Miller', 1)
#          - parties represented in those cases:
# 		('BEVERLY C SHIPMAN', 1)
#
#
#         AggregatedFirmInfo(161131016): Ken Fiedler Injury Law
#          - cases in subset: ['https://law.lexmachina.com/cases/2008976540']
#          - attys on those cases:
# 		('Kenneth Robert Fiedler Sr.', 1)
# 		('James Robert Anderson (Ken Fiedler Injury Law)', 1)
#          - parties represented in those cases:
# 		('Frances Ouzounis', 1)
# 		('Eleftherios Ouzounis', 1)
#
#
#         AggregatedFirmInfo(131251794): LAW OFFICES OF MARTHA AMAYA
#          - cases in subset: ['https://law.lexmachina.com/cases/2008977215']
#          - attys on those cases:
# 		('Brandon C. Stone', 1)
#          - parties represented in those cases:
# 		('Jhonny Leyva Bello', 1)
#
#
#         AggregatedFirmInfo(48555652): John N. Samaha
#          - cases in subset: ['https://law.lexmachina.com/cases/2008982796']
#          - attys on those cases:
# 		('John Norman Samaha', 1)
#          - parties represented in those cases:
# 		('Mattie Mae Pate', 1)
#
#
#         AggregatedFirmInfo(16242): The Miller Law Firm (millerlawpc.com)
#          - cases in subset: ['https://law.lexmachina.com/cases/2008989012']
#          - attys on those cases:
# 		('Brian Gerard Friel', 1)
# 		('Mark Edwin Miller', 1)
# 		('Benjamin W. Massarsky', 1)
# 		('Natalie Seales', 1)
#          - parties represented in those cases:
# 		('TD BANK, N.A.', 1)
#
#
#         AggregatedFirmInfo(1189325): Calvert Menicucci
#          - cases in subset: ['https://law.lexmachina.com/cases/2008989841']
#          - attys on those cases:
# 		('Sean R. Calvert', 1)
#          - parties represented in those cases:
# 		('Integrated Water Services, Inc.', 1)
#
#
#         AggregatedFirmInfo(9963047): Coppler Law Firm
#          - cases in subset: ['https://law.lexmachina.com/cases/2008989841']
#          - attys on those cases:
# 		('Gerald A. Coppler', 1)
# 		('Frank R. Coppler', 1)
# 		('John L. Appel', 1)
#          - parties represented in those cases:
# 		('Village of Taos Ski Valley', 1)
#
#
#         AggregatedFirmInfo(9134641): Law Office of Nikolaus W. Reed
#          - cases in subset: ['https://law.lexmachina.com/cases/2008990537']
#          - attys on those cases:
# 		('Nikolaus W. Reed', 1)
#          - parties represented in those cases:
# 		('Karin Parodi', 1)
#
#
#         AggregatedFirmInfo(1877106): Breskin Johnson & Townsend
#          - cases in subset: ['https://law.lexmachina.com/cases/2008992582']
#          - attys on those cases:
# 		('Cynthia J. Heidelberg', 1)
# 		('David Elliot Breskin', 1)
#          - parties represented in those cases:
# 		('Lawrence A. Thomas, DC, PS', 1)
# 		('BC Chiropractic', 1)
#
#
#         AggregatedFirmInfo(9972007): The Law Offices of Laura Hunt
#          - cases in subset: ['https://law.lexmachina.com/cases/2008992602']
#          - attys on those cases:
# 		('Laura M. Payne (The Law Offices of Laura Hunt)', 1)
#          - parties represented in those cases:
# 		('Evelyn Conerly', 1)
#
#
#         AggregatedFirmInfo(176728798): TheOneLawyer.Con
#          - cases in subset: ['https://law.lexmachina.com/cases/2008992602']
#          - attys on those cases:
# 		('Laura M. Payne (The Law Offices of Laura Hunt)', 1)
#          - parties represented in those cases:
# 		('Evelyn Conerly', 1)
#
#
#         AggregatedFirmInfo(8766906): Richard Harris Law Firm
#          - cases in subset: ['https://law.lexmachina.com/cases/2008995623']
#          - attys on those cases:
# 		('Jessica M. Leyva-Munoz', 1)
#          - parties represented in those cases:
# 		('Kristian Frias Acosta', 1)
# 		('Alanias Frias Acosta', 1)
#
#
#         AggregatedFirmInfo(95108177): Martinez/Tijerina
#          - cases in subset: ['https://law.lexmachina.com/cases/2009000656']
#          - attys on those cases:
# 		('Tomas Francisco Tijerina', 1)
# 		('Benigno [trey] Martinez III', 1)
#          - parties represented in those cases:
# 		('Dr. Raymundo Matar', 1)
#
#
#         AggregatedFirmInfo(8078855): Merlin Law Group
#          - cases in subset: ['https://law.lexmachina.com/cases/2009003949']
#          - attys on those cases:
# 		('Lucas Henry Morehouse', 1)
#          - parties represented in those cases:
# 		('Joyce Harvey', 1)
# 		('Jack Harvey', 1)
#
#
#         AggregatedFirmInfo(207090): Cadden & Fuller
#          - cases in subset: ['https://law.lexmachina.com/cases/2009009291']
#          - attys on those cases:
# 		('Thomas H. Cadden', 1)
#          - parties represented in those cases:
# 		('Cardiology Specialists of Orange County', 1)
#
#
#         AggregatedFirmInfo(133173438): Biller, Sachs & Robert
#          - cases in subset: ['https://law.lexmachina.com/cases/2009018543']
#          - attys on those cases:
# 		('Jon David Biller', 1)
# 		('Brianna Kastukevich Robert', 1)
#          - parties represented in those cases:
# 		('Indira Pereirakamath', 1)
# 		('Manish Chowdhary', 1)
#
#
#         AggregatedFirmInfo(15245341): Loree & Lipscomb
#          - cases in subset: ['https://law.lexmachina.com/cases/2009018723']
#          - attys on those cases:
# 		('Edwin Todd Lipscomb', 1)
# 		('Todd Lipscomb', 1)
# 		('Trevis Robert Loree', 1)
#          - parties represented in those cases:
# 		('Phyliss Gee', 1)
#
#
#         AggregatedFirmInfo(110233921): Deiker Voightmann Donovan
#          - cases in subset: ['https://law.lexmachina.com/cases/2009021616']
#          - attys on those cases:
# 		('Douglas F. Dieker', 1)
#          - parties represented in those cases:
# 		('Keith A Henderson', 1)
# 		('Tammy J Henderson', 1)
#
#
#         AggregatedFirmInfo(8519460): The Crew Law Firm
#          - cases in subset: ['https://law.lexmachina.com/cases/2009021505']
#          - attys on those cases:
# 		('Paxton N. Crew', 1)
#          - parties represented in those cases:
# 		('Grey Rock Gathering & Marketing, LLC', 1)
#
#
#         AggregatedFirmInfo(9589667): Tabak, Mellusi & Shisha
#          - cases in subset: ['https://law.lexmachina.com/cases/2009021505']
#          - attys on those cases:
# 		('Jacob Shisha', 1)
#          - parties represented in those cases:
# 		('Grey Rock Gathering & Marketing, LLC', 1)
#
#
#         AggregatedFirmInfo(40358230): Thompson, d'Entremont & Robin
#          - cases in subset: ['https://law.lexmachina.com/cases/2009022171']
#          - attys on those cases:
# 		("James Francis d'Entremont", 1)
# 		('Steven C. Thompson', 1)
# 		('Corey John Hebert', 1)
# 		('Sarah Elizabeth Hunter', 1)
#          - parties represented in those cases:
# 		('Sarita A Dixon', 1)
# 		('Troy J Dixon', 1)
#
#
#         AggregatedFirmInfo(17284817): Shearman
#          - cases in subset: ['https://law.lexmachina.com/cases/2009028169']
#          - attys on those cases:
# 		('Brian Gerard Shearman', 1)
# 		('John Henry Denenea Jr.', 1)
# 		('Brandon Patrick Shearman', 1)
#          - parties represented in those cases:
# 		('James Gares', 1)
#
#
#         AggregatedFirmInfo(75226343): Rosenbaum Law Group (rosenbaumlawgroup.com)
#          - cases in subset: ['https://law.lexmachina.com/cases/2009028580']
#          - attys on those cases:
# 		('Gretchen L. Mandekor', 1)
# 		('Timothy W. Grabe', 1)
#          - parties represented in those cases:
# 		('Richard Pachmayr', 1)
#
#
#         AggregatedFirmInfo(146230590): Strickland Law Firm (stricklandlawfirm.com)
#          - cases in subset: ['https://law.lexmachina.com/cases/2009031579']
#          - attys on those cases:
# 		('Ryan Thomas Strickland', 1)
#          - parties represented in those cases:
# 		('Paris Pence', 1)
# 		('Mary Ritchie', 1)
#
#
#         AggregatedFirmInfo(2722432): Kustoff & Phipps
#          - cases in subset: ['https://law.lexmachina.com/cases/2009031383']
#          - attys on those cases:
# 		('Taylor Lynn Crull', 1)
#          - parties represented in those cases:
# 		('Adam Ashley', 1)
# 		('Adam Ashely', 1)
# 		('Alison Ashley', 1)
#
#
#         AggregatedFirmInfo(90700948): Kustoff & Sanders
#          - cases in subset: ['https://law.lexmachina.com/cases/2009031383']
#          - attys on those cases:
# 		('Daniel Oren Kustoff', 1)
# 		('Melanie Hessler Sanders', 1)
#          - parties represented in those cases:
# 		('Adam Ashley', 1)
# 		('Adam Ashely', 1)
# 		('Alison Ashley', 1)
#
#
#         AggregatedFirmInfo(10915295): Pourciau Law Firm
#          - cases in subset: ['https://law.lexmachina.com/cases/2009035235']
#          - attys on those cases:
# 		('Damon R. Pourciau', 1)
#          - parties represented in those cases:
# 		('Dennis Daigle, III', 1)
# 		('Kim Lombas', 1)
# 		('Michelle Trouilliet', 1)
# 		('Patrick Daigle', 1)
# 		('Eric Daigle', 1)
#
#
#         AggregatedFirmInfo(7719447): Fishman Haygood
#          - cases in subset: ['https://law.lexmachina.com/cases/2009035693']
#          - attys on those cases:
# 		('Kerry James Miller', 1)
#          - parties represented in those cases:
# 		('Dwight D Landry', 1)
#
#
#         AggregatedFirmInfo(16): Greenberg Traurig
#          - cases in subset: ['https://law.lexmachina.com/cases/2009041164']
#          - attys on those cases:
# 		('Robert C. Epstein', 1)
# 		('Samantha Varsalona', 1)
# 		('Ruth D. Kirshner', 1)
#          - parties represented in those cases:
# 		('AMEREAM LLC', 1)
#
#
#         AggregatedFirmInfo(178035927): The Law Office of Jeffrey Coniaris
#          - cases in subset: ['https://law.lexmachina.com/cases/2009044340']
#          - attys on those cases:
# 		('Jeffrey C. Coniaris', 1)
#          - parties represented in those cases:
# 		('Wellness Medical Center LLC', 1)
#
#
#         AggregatedFirmInfo(9200999): Mark S Humphreys
#          - cases in subset: ['https://law.lexmachina.com/cases/2009050224']
#          - attys on those cases:
# 		('Mark Steven Humphreys', 1)
#          - parties represented in those cases:
# 		('Yvonne Marie Coyle', 1)
#
#
#         AggregatedFirmInfo(6156058): Sisam & Associates
#          - cases in subset: ['https://law.lexmachina.com/cases/2009063331']
#          - attys on those cases:
# 		('Joshua Howard Sisam', 1)
#          - parties represented in those cases:
# 		('Jared Carter', 1)
#
#
#         AggregatedFirmInfo(178542149): Sisman & Associates
#          - cases in subset: ['https://law.lexmachina.com/cases/2009063331']
#          - attys on those cases:
# 		('Joshua H. Sisman', 1)
#          - parties represented in those cases:
# 		('Jared Carter', 1)
#
#
#         AggregatedFirmInfo(155150197): Usery & Associates
#          - cases in subset: ['https://law.lexmachina.com/cases/2009066535']
#          - attys on those cases:
# 		('Logan A. Carducci', 1)
# 		('Rachel Joan Fain', 1)
#          - parties represented in those cases:
# 		('The Phoenix Insurance Company', 1)
#
#
#         AggregatedFirmInfo(8359481): Laborde Earles Law Firm
#          - cases in subset: ['https://law.lexmachina.com/cases/2009079130']
#          - attys on those cases:
# 		('Nicholas Ryan Rockforte', 1)
# 		('Mary Katherine Cryar', 1)
# 		('Wesley Kyle Elmer', 1)
# 		('David Charles Laborde Sr.', 1)
#          - parties represented in those cases:
# 		('Joseph Harrison', 1)
# 		('Susan Harrison', 1)
#
#
#         AggregatedFirmInfo(8184788): Woodrow & Peluso
#          - cases in subset: ['https://law.lexmachina.com/cases/2009083198']
#          - attys on those cases:
# 		('Steven Lezell Woodrow (Woodrow & Peluso)', 1)
# 		('Patrick Harry Peluso', 1)
#          - parties represented in those cases:
# 		('Andrea Audish', 1)
#
#
#         AggregatedFirmInfo(9257324): Mann Law Firm (sbmannlaw.com)
#          - cases in subset: ['https://law.lexmachina.com/cases/2009083198']
#          - attys on those cases:
# 		('Simon B. Mann', 1)
#          - parties represented in those cases:
# 		('Andrea Audish', 1)
#
#
#         AggregatedFirmInfo(103469555): Tapper Law Firm
#          - cases in subset: ['https://law.lexmachina.com/cases/2009090043']
#          - attys on those cases:
# 		('Clinton Lee Tapper', 1)
#          - parties represented in those cases:
# 		('Corey Walker', 1)
# 		('Rebecca Walker', 1)
#
#
#         AggregatedFirmInfo(176659861): KB Law
#          - cases in subset: ['https://law.lexmachina.com/cases/2009090043']
#          - attys on those cases:
# 		('Christopher R. Burke', 1)
# 		('Kenji Kozuma', 1)
#          - parties represented in those cases:
# 		('Corey Walker', 1)
# 		('Rebecca Walker', 1)
#
#
#         AggregatedFirmInfo(48337537): Mansell Engel & Cole
#          - cases in subset: ['https://law.lexmachina.com/cases/2009090062']
#          - attys on those cases:
# 		('Keith French Givens', 1)
# 		('Steven Scott Mansell', 1)
#          - parties represented in those cases:
# 		('Doug Floyd', 1)
#
#
#         AggregatedFirmInfo(8750962): The Kirby G. Smith Law Firm
#          - cases in subset: ['https://law.lexmachina.com/cases/2009092668']
#          - attys on those cases:
# 		('Amanda Maree Brookhuis', 1)
#          - parties represented in those cases:
# 		('Angea Garner', 1)
#
#
#         AggregatedFirmInfo(8742777): The Myer Law Firm
#          - cases in subset: ['https://law.lexmachina.com/cases/2009097767']
#          - attys on those cases:
# 		('Mari Lynn Myer', 1)
#          - parties represented in those cases:
# 		('Wayne Suss', 1)
#
#
#         AggregatedFirmInfo(37162441): Chad T. Wilson Law Firm
#          - cases in subset: ['https://law.lexmachina.com/cases/2009097942']
#          - attys on those cases:
# 		('Chad Troy Wilson', 1)
# 		('Amanda Jean Fulton', 1)
#          - parties represented in those cases:
# 		('Ashley Burke', 1)
# 		('Walter Burke', 1)
#
#
#         AggregatedFirmInfo(2336716): Murphy & Riley
#          - cases in subset: ['https://law.lexmachina.com/cases/2009132101']
#          - attys on those cases:
# 		('Chase Howes Kennedy', 1)
#          - parties represented in those cases:
# 		('Phenix Mutual Fire Insurance Co.', 1)
#
#
#         AggregatedFirmInfo(53300625): Weisser Elazar & Kantor
#          - cases in subset: ['https://law.lexmachina.com/cases/2009274941']
#          - attys on those cases:
# 		('Aaron David Silvers', 1)
#          - parties represented in those cases:
# 		('Teresa Mitsch', 1)
# 		('Mike Mitsch', 1)
#
#
#         AggregatedFirmInfo(123926422): Schilling & Silvers
#          - cases in subset: ['https://law.lexmachina.com/cases/2009274941']
#          - attys on those cases:
# 		('Jeremy Theodore Schilling', 1)
#          - parties represented in those cases:
# 		('Teresa Mitsch', 1)
# 		('Mike Mitsch', 1)
#
#
#         AggregatedFirmInfo(28948): Baker, Donelson, Bearman, Caldwell & Berkowitz
#          - cases in subset: ['https://law.lexmachina.com/cases/2009279871']
#          - attys on those cases:
# 		('Melissa Gayle Vest', 1)
# 		('Kirsten Diane Vesel', 1)
#          - parties represented in those cases:
# 		('Matheus Lumber Company, Inc.', 1)
#
#
#         AggregatedFirmInfo(20668302): Droder & Miller Co.
#          - cases in subset: ['https://law.lexmachina.com/cases/2009282881']
#          - attys on those cases:
# 		('Donald Alan Lane', 1)
#          - parties represented in those cases:
# 		('Brian Daron', 1)
# 		('Elizabeth Daron', 1)
#
#
#         AggregatedFirmInfo(1562871): Whitten Burrage
#          - cases in subset: ['https://law.lexmachina.com/cases/2009295596']
#          - attys on those cases:
# 		('Michael Sean Burrage', 1)
# 		('Reginald Neil Whitten', 1)
# 		('John Revell Parrish', 1)
#          - parties represented in those cases:
# 		('Gail Offermann', 1)
#
#
#         AggregatedFirmInfo(49137312): Harp Law Group
#          - cases in subset: ['https://law.lexmachina.com/cases/2009295596']
#          - attys on those cases:
# 		('Bryce P. Harp', 1)
#          - parties represented in those cases:
# 		('Gail Offermann', 1)
#
#
#         AggregatedFirmInfo(180856018): Dudugjian Law
#          - cases in subset: ['https://law.lexmachina.com/cases/2009298248']
#          - attys on those cases:
# 		('Robert Paul Dudugjian', 1)
#          - parties represented in those cases:
# 		('Harinder Khera', 1)
# 		('Gurpreet Khera', 1)
#
#
#         AggregatedFirmInfo(2444814): Harrison Law Group (harrisonlawgroup.com)
#          - cases in subset: ['https://law.lexmachina.com/cases/2009300652']
#          - attys on those cases:
# 		('Adam Craig Harrison', 1)
# 		('Eli Robbins', 1)
# 		('Andrew Paul Gorini', 1)
#          - parties represented in those cases:
# 		('United States of America', 1)
# 		('Aarow Electrical Solutions, LLC', 1)
#
#
#         AggregatedFirmInfo(96406470): Council Law Firm
#          - cases in subset: ['https://law.lexmachina.com/cases/2009301074']
#          - attys on those cases:
# 		('Benny D. Council', 1)
#          - parties represented in those cases:
# 		('Yeldy Clark', 1)
#
#
#         AggregatedFirmInfo(181970399): (Unknown Law Firm)
#          - cases in subset: ['https://law.lexmachina.com/cases/2009301074']
#          - attys on those cases:
# 		('Mario A. Sanchez Jr', 1)
#          - parties represented in those cases:
# 		('Yeldy Clark', 1)
#
#
#         AggregatedFirmInfo(1310225): Fullerton & Knowles
#          - cases in subset: ['https://law.lexmachina.com/cases/2009306259']
#          - attys on those cases:
# 		('James Durling Fullerton', 1)
#          - parties represented in those cases:
# 		('Coordinated Systems Consulting, Inc.', 1)
# 		('United States of America', 1)
#
#
#         AggregatedFirmInfo(10915889): Robbins Law Group
#          - cases in subset: ['https://law.lexmachina.com/cases/2009306259']
#          - attys on those cases:
# 		('Seth Adam Robbins', 1)
#          - parties represented in those cases:
# 		('United States of America, for the use and benefit of Coordinated Systems Consulting, Inc.', 1)
# 		('Coordinated Systems Consulting, Inc.', 1)
# 		('United States of America', 1)
#
#
#         AggregatedFirmInfo(133808749): Espinal Law
#          - cases in subset: ['https://law.lexmachina.com/cases/2009316408']
#          - attys on those cases:
# 		('Michael Espinal', 1)
#          - parties represented in those cases:
# 		('Randy Dykes', 1)
# 		('Kerri Deland', 1)
#
#
#         AggregatedFirmInfo(11155652): Wilkinson Goeller Modesitt Wilkinson & Drummy
#          - cases in subset: ['https://law.lexmachina.com/cases/2009316588']
#          - attys on those cases:
# 		('David C. Hamilton', 1)
#          - parties represented in those cases:
# 		('Corina Fouss', 1)
# 		('Jamie Fouss', 1)
#
#
#         AggregatedFirmInfo(20312662): Frankl Law Firm
#          - cases in subset: ['https://law.lexmachina.com/cases/2009324194']
#          - attys on those cases:
# ...
#          - attys on those cases:
# 		('Dennis Hernandez', 1)
#          - parties represented in those cases:
# 		('Elin Li', 1)
#
#
#         AggregatedFirmInfo(79846889): Cremeens Law Group
#          - cases in subset: ['https://law.lexmachina.com/cases/2009431209']
#          - attys on those cases:
# 		('Scott Ira Simkins', 1)
#          - parties represented in those cases:
# 		('Elin Li', 1)
#
#
#         AggregatedFirmInfo(155826031): Duke Holzman Photiadis & Gresens
#          - cases in subset: ['https://law.lexmachina.com/cases/2009431253']
#          - attys on those cases:
# 		('Christopher M. Berloth', 1)
# 		('Thomas David Lyons', 1)
#          - parties represented in those cases:
# 		('Wynstream Holdings Limited', 1)
# 		('Techfrys Corporation', 1)
#
#
#         AggregatedFirmInfo(162503887): Chevy Chase Law
#          - cases in subset: ['https://law.lexmachina.com/cases/2009431856']
#          - attys on those cases:
# 		('Allan David Poteshman', 1)
#          - parties represented in those cases:
# 		('Ebony Shephard', 1)
#
#
#         AggregatedFirmInfo(29465396): The Kendrick Law Firm
#          - cases in subset: ['https://law.lexmachina.com/cases/2009529321']
#          - attys on those cases:
# 		('Jon Michael Kendrick', 1)
#          - parties represented in those cases:
# 		('Florida Keys Electric, Inc.', 1)
#
#
#         AggregatedFirmInfo(30325525): Mark A. Gould, P.C., The Law
#          - cases in subset: ['https://law.lexmachina.com/cases/2009529469']
#          - attys on those cases:
# 		('Mark Alan Gould', 1)
#          - parties represented in those cases:
# 		('Michael Wyatt', 1)
#
#
#         AggregatedFirmInfo(8670162): Florin Roebig
#          - cases in subset: ['https://law.lexmachina.com/cases/2009532984']
#          - attys on those cases:
# 		('Chase Patrick Florin', 1)
# 		('Kavon Patrick Smith', 1)
# 		('Hal Scott Weitzenfeld', 1)
#          - parties represented in those cases:
# 		('Shauna Yeager', 1)
# 		('Jason Yeager', 1)
#
#
#         AggregatedFirmInfo(93753485): Loftus & Eisenberg
#          - cases in subset: ['https://law.lexmachina.com/cases/2009596217']
#          - attys on those cases:
# 		('Davina Rae Dipaolo', 1)
#          - parties represented in those cases:
# 		('Summer Campbell', 1)
#
#
#         AggregatedFirmInfo(2674548): McCorkle & Johnson
#          - cases in subset: ['https://law.lexmachina.com/cases/2009752975']
#          - attys on those cases:
# 		('David Hughes Johnson', 1)
#          - parties represented in those cases:
# 		('United States of America for the use and benefit of Blankenship Group, Inc.', 1)
# 		('Blankenship Group, Inc.', 1)
#
#
#         AggregatedFirmInfo(8075053): Landry & Swarr
#          - cases in subset: ['https://law.lexmachina.com/cases/2009753374']
#          - attys on those cases:
# 		('Matthew C. Clark (Landry & Swarr)', 1)
# 		('Mickey P. Landry', 1)
# 		('Frank Joseph Swarr', 1)
#          - parties represented in those cases:
# 		('Robert J. McElwee', 1)
#
#
#         AggregatedFirmInfo(8079040): Nemeroff Law Firm
#          - cases in subset: ['https://law.lexmachina.com/cases/2009753374']
#          - attys on those cases:
# 		("Jeffrey A. O'Connell (Nemeroff Law Firm)", 1)
#          - parties represented in those cases:
# 		('Robert J. McElwee', 1)
#
#
#         AggregatedFirmInfo(183908896): CHERYL KIDD LAW
#          - cases in subset: ['https://law.lexmachina.com/cases/2009753564']
#          - attys on those cases:
# 		('Cheryl A. Kidd', 1)
#          - parties represented in those cases:
# 		('Delmous Vance, III', 1)
#
#
#         AggregatedFirmInfo(880344): Pittman, Germany, Roberts & Welsh
#          - cases in subset: ['https://law.lexmachina.com/cases/2009756857']
#          - attys on those cases:
# 		('Carl Victor Welsh III', 1)
# 		('Ann Russell Chandler', 1)
# 		('Crymes Morgan Pittman', 1)
#          - parties represented in those cases:
# 		('Derrick Hardy', 1)
#
#
#         AggregatedFirmInfo(8701647): Law Office of Nicholas M. Graphia
#          - cases in subset: ['https://law.lexmachina.com/cases/2009757562']
#          - attys on those cases:
# 		('Nicholas Michael Graphia', 1)
#          - parties represented in those cases:
# 		('Richard Cook', 1)
#
#
#         AggregatedFirmInfo(146160050): Loyd J. Bourgeois
#          - cases in subset: ['https://law.lexmachina.com/cases/2009757562']
#          - attys on those cases:
# 		('Loyd Joseph Bourgeois Jr', 1)
#          - parties represented in those cases:
# 		('Richard Cook', 1)
#
#
#         AggregatedFirmInfo(149749380): Didriksen Law Firm
#          - cases in subset: ['https://law.lexmachina.com/cases/2009757562']
#          - attys on those cases:
# 		('Loyd Joseph Bourgeois Jr', 1)
#          - parties represented in those cases:
# 		('Richard Cook', 1)
#
#
#         AggregatedFirmInfo(87457003): Kracht Madison Huddleston
#          - cases in subset: ['https://law.lexmachina.com/cases/2009765150']
#          - attys on those cases:
# 		('John Meek Madison III', 1)
#          - parties represented in those cases:
# 		('Vulcan Construction Materials LLC', 1)
#
#
#         AggregatedFirmInfo(1178139): Aaron & Wilson
#          - cases in subset: ['https://law.lexmachina.com/cases/2009767597']
#          - attys on those cases:
# 		('Robert Scott Aaron', 1)
#          - parties represented in those cases:
# 		('Pace Supply Corp.', 1)
#
#
#         AggregatedFirmInfo(8121553): Hatcher & Rundel
#          - cases in subset: ['https://law.lexmachina.com/cases/2009767597']
#          - attys on those cases:
# 		('William Wallace Hatcher Jr.', 1)
#          - parties represented in those cases:
# 		('Pace Supply Corp.', 1)
#
#
#         AggregatedFirmInfo(173955): Jackson & Campbell
#          - cases in subset: ['https://law.lexmachina.com/cases/2009771688']
#          - attys on those cases:
# 		('Christopher Allan Glaser', 1)
# 		('Christopher Paul Ferragamo', 1)
# 		('Caroline Lee-Ghosal Lee-G', 1)
#          - parties represented in those cases:
# 		('Avance Title, LLC', 1)
# 		('Doma Title Insurance, Inc.', 1)
#
#
#         AggregatedFirmInfo(431423): Carr Maloney
#          - cases in subset: ['https://law.lexmachina.com/cases/2009771688']
#          - attys on those cases:
# 		('John Peter Glaws IV', 1)
#          - parties represented in those cases:
# 		('Avance Title, LLC', 1)
#
#
#         AggregatedFirmInfo(48437859): Houghtaling Law Firm
#          - cases in subset: ['https://law.lexmachina.com/cases/2009772379']
#          - attys on those cases:
# 		('Brian James Houghtaling', 1)
#          - parties represented in those cases:
# 		('Interior Design Associates, Inc.', 1)
# 		('Interior Design Holding Co., LLC', 1)
#
#
#         AggregatedFirmInfo(67920311): Huber, Thomas & Marcelle
#          - cases in subset: ['https://law.lexmachina.com/cases/2009772379']
#          - attys on those cases:
# 		('Logan Schonekas Albertine', 1)
# 		('Stephen Michael Huber', 1)
# 		('Lacey McCoy Moghis', 1)
#          - parties represented in those cases:
# 		('Interior Design Associates, Inc.', 1)
# 		('Interior Design Holding Co., LLC', 1)
#
#
#         AggregatedFirmInfo(2154519): Ayers & Ayers
#          - cases in subset: ['https://law.lexmachina.com/cases/2009776462']
#          - attys on those cases:
# 		('Jonathan Parkey Ayers', 1)
#          - parties represented in those cases:
# 		('Rhonda Lewandowski', 1)
# 		('James Lewandowski', 1)
#
#
#         AggregatedFirmInfo(15281705): Rowe Law Firm (rowelaw.net)
#          - cases in subset: ['https://law.lexmachina.com/cases/2009787561']
#          - attys on those cases:
# 		('Adrian Paul Smith', 1)
#          - parties represented in those cases:
# 		('Cavich Prudhomme', 1)
# 		('Larry Washington', 1)
#
#
#         AggregatedFirmInfo(57671147): Doran & Cawthorne
#          - cases in subset: ['https://law.lexmachina.com/cases/2009787561']
#          - attys on those cases:
# 		('Pride Justin Doran', 1)
# 		('Quincy L. Cawthorne', 1)
# 		('Raven C. Boxie', 1)
# 		('Larry Washington', 1)
# 		('Cavich Prudhomme', 1)
# 		('Errin Green', 1)
#          - parties represented in those cases:
# 		('Cavich Prudhomme', 1)
# 		('Larry Washington', 1)
#
#
#         AggregatedFirmInfo(10918894): The King Firm (kinginjuryfirm.com)
#          - cases in subset: ['https://law.lexmachina.com/cases/2009787830']
#          - attys on those cases:
# 		('Jason F. Giles', 1)
# 		('Brian Wayne King', 1)
#          - parties represented in those cases:
# 		('Amy Alvarez', 1)
#
#
#         AggregatedFirmInfo(171699659): Ryan A. Creel
#          - cases in subset: ['https://law.lexmachina.com/cases/2009787830']
#          - attys on those cases:
# 		('Ryan A. Creel', 1)
#          - parties represented in those cases:
# 		('Amy Alvarez', 1)
#
#
#         AggregatedFirmInfo(6285073): Broussard & David
#          - cases in subset: ['https://law.lexmachina.com/cases/2009792400']
#          - attys on those cases:
# 		('John Salm Alford', 1)
#          - parties represented in those cases:
# 		('Gretchen Brown', 1)
#
#
#         AggregatedFirmInfo(34350410): Irpino, Avin & Hawkins
#          - cases in subset: ['https://law.lexmachina.com/cases/2009792400']
#          - attys on those cases:
# 		('Anthony D. Irpino Sr.', 1)
# 		('Dustin Louis Poche', 1)
#          - parties represented in those cases:
# 		('Gretchen Brown', 1)
#
#
#         AggregatedFirmInfo(769378): Kenison & Dudley
#          - cases in subset: ['https://law.lexmachina.com/cases/2009798002']
#          - attys on those cases:
# 		('Thomas Elihue Dudley III', 1)
#          - parties represented in those cases:
# 		('Brandon Julian', 1)
# 		('Kalah Julian', 1)
#
#
#         AggregatedFirmInfo(612392): Wright & Reihner
#          - cases in subset: ['https://law.lexmachina.com/cases/2009807722']
#          - attys on those cases:
# 		('Joseph T. Wright Jr.', 1)
# 		('Danielle M. Mulcahey', 1)
#          - parties represented in those cases:
# 		('Paula Scotchlas', 1)
#
#
#         AggregatedFirmInfo(58218991): Delphin Law Offices
#          - cases in subset: ['https://law.lexmachina.com/cases/2009813060']
#          - attys on those cases:
# 		('Mark Anthony Delphin II', 1)
#          - parties represented in those cases:
# 		('Shereen Taha', 1)
#
#
#         AggregatedFirmInfo(184613038): Mark A. Delphin, II, Esq.
#          - cases in subset: ['https://law.lexmachina.com/cases/2009813060']
#          - attys on those cases:
# 		('Shereen Taha', 1)
#          - parties represented in those cases:
# 		('Shereen Taha', 1)
#
#
#         AggregatedFirmInfo(26131872): Law Offices of Frank J D'Amico, Jr
#          - cases in subset: ['https://law.lexmachina.com/cases/2009817665']
#          - attys on those cases:
# 		("Frank Jacob D'Amico Jr", 1)
#          - parties represented in those cases:
# 		('Mark Mentel', 1)
#
#
#         AggregatedFirmInfo(178880163): Law Office of Stephen White
#          - cases in subset: ['https://law.lexmachina.com/cases/2009818006']
#          - attys on those cases:
# 		('Stephen E. White', 1)
#          - parties represented in those cases:
# 		('Apollo Asset Management Inc.', 1)
#
#
#         AggregatedFirmInfo(164566905): Thomas J. Morgan
#          - cases in subset: ['https://law.lexmachina.com/cases/2009821733']
#          - attys on those cases:
# 		('Alicia Dennis', 1)
# 		('Brian Dennis', 1)
#          - parties represented in those cases:
# 		('Alicia Dennis', 1)
# 		('Brian Dennis', 1)
#
#
#         AggregatedFirmInfo(146312107): Hearn Law Firm (hearnlawfirm.net)
#          - cases in subset: ['https://law.lexmachina.com/cases/2009830717']
#          - attys on those cases:
# 		('Philip Carey Hearn', 1)
# 		('Charles Cassidy Cole', 1)
#          - parties represented in those cases:
# 		('Ashley Jones', 1)
#
#
#         AggregatedFirmInfo(48575757): Donovan & Lawler
#          - cases in subset: ['https://law.lexmachina.com/cases/2009834275']
#          - attys on those cases:
# 		('Clare Elizabeth Donovan', 1)
#          - parties represented in those cases:
# 		('JAMES BEASLEY', 1)
# 		('JEANETTE BEASLEY', 1)
#
#
#         AggregatedFirmInfo(181837742): Insurance Claim Lawyers
#          - cases in subset: ['https://law.lexmachina.com/cases/2009834976']
#          - attys on those cases:
# 		('Thomas Lee Myers', 1)
#          - parties represented in those cases:
# 		('Sarah Diano', 1)
# 		('Philip Diano', 1)
#
#
#         AggregatedFirmInfo(13614269): Agrait Llado Law Office
#          - cases in subset: ['https://law.lexmachina.com/cases/2009838612']
#          - attys on those cases:
# 		('Jaime F. Agrait-Llado', 1)
#          - parties represented in those cases:
# 		('Caroline Herrero-Torres', 1)
#
#
#         AggregatedFirmInfo(48316849): Kerley Schaffer
#          - cases in subset: ['https://law.lexmachina.com/cases/2009843367']
#          - attys on those cases:
# 		('John Edward Kerley Jr.', 1)
# 		('Dylan Leon Schaffer', 1)
# 		('Edward Kerley', 1)
#          - parties represented in those cases:
# 		('Anthony Vecchio', 1)
# 		('Catherine Vecchio', 1)
#
#
#         AggregatedFirmInfo(43592760): Cokinos Young
#          - cases in subset: ['https://law.lexmachina.com/cases/2009843763']
#          - attys on those cases:
# 		('Christopher Gerald Burwell', 1)
# 		('Johnathan Malcolm Bailey', 1)
#          - parties represented in those cases:
# 		("Frank's Paving Company, Inc.", 1)
# 		("United States of America, For Use and in Benefit of Frank's Paving Company, Inc.", 1)
#
#
#         AggregatedFirmInfo(110340440): DiOrio & Sereni
#          - cases in subset: ['https://law.lexmachina.com/cases/2009843796']
#          - attys on those cases:
# 		('Robert B. George', 1)
#          - parties represented in those cases:
# 		('HELENE B. MORRIS', 1)
#
#
#         AggregatedFirmInfo(159562931): Doehling Law
#          - cases in subset: ['https://law.lexmachina.com/cases/2009843951']
#          - attys on those cases:
# 		('Joseph Henry Azbell', 1)
# 		('Keller Andrew Caubarreaux', 1)
#          - parties represented in those cases:
# 		("Susan O'Brien", 1)
#
#
#         AggregatedFirmInfo(44955954): Lewin & Baglio
#          - cases in subset: ['https://law.lexmachina.com/cases/2009861784']
#          - attys on those cases:
# 		('Michael Baglio I', 1)
# 		('William A. Benson', 1)
#          - parties represented in those cases:
# 		('New Horizon Surgical Center, LLC', 1)
#
#
#         AggregatedFirmInfo(12781861): William Stark
#          - cases in subset: ['https://law.lexmachina.com/cases/2009887120']
#          - attys on those cases:
# 		('Evan Michael Stark', 1)
#          - parties represented in those cases:
# 		('Marla Stark', 1)
# 		('William Stark', 1)
#
#
#         AggregatedFirmInfo(145706674): Krielow Law Firm
#          - cases in subset: ['https://law.lexmachina.com/cases/2009887120']
#          - attys on those cases:
# 		('Kendall John Krielow', 1)
#          - parties represented in those cases:
# 		('Marla Stark', 1)
# 		('William Stark', 1)
#
#
#         AggregatedFirmInfo(146106516): Stark Law Firm (williamstark.com)
#          - cases in subset: ['https://law.lexmachina.com/cases/2009887120']
#          - attys on those cases:
# 		('Richard Christopher Breaux', 1)
#          - parties represented in those cases:
# 		('Marla Stark', 1)
# 		('William Stark', 1)
#
#
#         AggregatedFirmInfo(45200100): MONTGOMERY McCRACKEN WALKER & RHOADS
#          - cases in subset: ['https://law.lexmachina.com/cases/2009887384']
#          - attys on those cases:
# 		('Vincent M. De Orchis', 1)
# 		('Matteo Bonuzzi', 1)
#          - parties represented in those cases:
# 		('STONELINE GROUP, LLC', 1)
#
#
#         AggregatedFirmInfo(78419503): Bellver Espinosa Law Firm
#          - cases in subset: ['https://law.lexmachina.com/cases/2009899906']
#          - attys on those cases:
# 		('Alejandro Bellver-Espinosa', 1)
#          - parties represented in those cases:
# 		('Mayra Guzmn-Kaslow', 1)
#
#
#         AggregatedFirmInfo(155587159): Law Offices of Eric A. Shore
#          - cases in subset: ['https://law.lexmachina.com/cases/2009914142']
#          - attys on those cases:
# 		('Steven A. Jarvis', 1)
#          - parties represented in those cases:
# 		('Krystal Lattomus', 1)
